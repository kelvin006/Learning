# %%
library(ggplot2)
library(dplyr)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
gapminder
# Out:
# Error in eval(expr, envir, enclos): object 'gapminder' not found
# Traceback:

# %%
search()
# Out:
#  [1] ".GlobalEnv"        "package:dplyr"     "package:gapminder"
#  [4] "package:ggplot2"   "jupyter:irkernel"  "package:stats"
#  [7] "package:graphics"  "package:grDevices" "package:utils"
# [10] "package:datasets"  "package:methods"   "Autoloads"
# [13] "package:base"

# %%
library(gapminder)

# %%
ggplot(gapminder%>%filter(year == 1967), aes(y = gdpPercap, x = lifeExp)) + geom_point() + scale_y_log10() + 
geom_smooth(method ="lm")
# Out:
# plot without title

# %%
head(gapminder)
# Out:
#   country     continent year lifeExp pop      gdpPercap
# 1 Afghanistan Asia      1952 28.801   8425333 779.4453
# 2 Afghanistan Asia      1957 30.332   9240934 820.8530
# 3 Afghanistan Asia      1962 31.997  10267083 853.1007
# 4 Afghanistan Asia      1967 34.020  11537966 836.1971
# 5 Afghanistan Asia      1972 36.088  13079460 739.9811
# 6 Afghanistan Asia      1977 38.438  14880372 786.1134
